# %%
import json
import os
import numpy as np
import kagglehub
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay, accuracy_score, f1_score, roc_curve
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, BatchNormalization, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow as tf
# Out:
# 2025-04-19 20:40:54.275042: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-19 20:40:54.291146: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745095254.311604    4005 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745095254.317780    4005 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-19 20:40:54.338149: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
SAVE_PATH = '/home/ec2-user/work/final_artifacts'
if not os.path.exists(SAVE_PATH):
    os.mkdir(SAVE_PATH)

# %%
SEED = 0
BATCH_SIZE = 32
HEIGHT, WIDTH = 256, 256

# %% [markdown]
# ---
# ### Classification model
# Continuous target (between 0-1)

# %%
# https://www.kaggle.com/datasets/ninadaithal/imagesoasis
data_dir = kagglehub.dataset_download("ninadaithal/imagesoasis")
print("Path to dataset files:", data_dir)
# Out:
# Path to dataset files: /home/ec2-user/.cache/kagglehub/datasets/ninadaithal/imagesoasis/versions/1

# %%
labels, images = [], []
for root, dirs, files in os.walk(data_dir):
    for file in files:
        file = os.path.join(root, file)
        if file.endswith('.jpg'):
            images.append(file)
            labels.append(file.split('/')[-2].replace(' ', ''))
del root, dirs, files, file, data_dir

# %%
df = pd.DataFrame({'images': images, 'labels': labels})
df = pd.concat([
    df[df['labels']=='ModerateDementia'],
    df[df['labels']=='MildDementia'],
    df[df['labels']=='VerymildDementia'],
    df[df['labels']=='NonDemented'].sample(n=25000, replace=False, random_state=SEED),
]).sample(frac=1., replace=False, random_state=SEED)
df_train_cls, df_test_cls = train_test_split(
    df, test_size=10000, shuffle=True, random_state=SEED, stratify=df['labels']
)
df_train_cls, df_val_cls = train_test_split(
    df_train_cls, test_size=10000, shuffle=True, random_state=SEED, stratify=df_train_cls['labels']
)
del df, labels, images

# %%
weights = df_train_cls['labels'].value_counts()
weights = weights.sum() / (weights.shape[0] * weights)
df_train_cls['weights'] = df_train_cls['labels'].map(weights)
df_val_cls['weights'] = df_val_cls['labels'].map(weights)
df_test_cls['weights'] = df_test_cls['labels'].map(weights)
del weights

# %%
def label_mapping(y):
    if y == 'NonDemented':
        return 0.
    if y == 'VerymildDementia':
        return 1/3
    if y == 'MildDementia':
        return 2/3
    if y == 'ModerateDementia':
        return 1.
    raise KeyError
def label_mapping_inv(y):
    if 0. <= y < 0.25:
        return 'NonDemented'
    if 0.25 <= y < 0.5:
        return 'VerymildDementia'
    if 0.5 <= y < 0.75:
        return 'MildDementia'
    if 0.75 <= y <= 1.:
        return 'ModerateDementia'
    raise KeyError

# %%
df_train_cls['labels'] = df_train_cls['labels'].apply(label_mapping)
df_val_cls['labels'] = df_val_cls['labels'].apply(label_mapping)
df_test_cls['labels'] = df_test_cls['labels'].apply(label_mapping)

# %%
def datagen_cls(df):
    return ImageDataGenerator(
        rotation_range=0.,
        width_shift_range=0.,
        height_shift_range=0.,
        shear_range=0.,
        zoom_range=0.,
        channel_shift_range=0.,
        horizontal_flip=False,
        vertical_flip=False,
        validation_split=0.,
        rescale=1/255,
        fill_mode='constant',
        cval=0.,
    ).flow_from_dataframe(
        df,
        x_col='images',
        y_col='labels',
        weight_col='weights',
        class_mode='raw',
        color_mode='rgb',
        target_size=(HEIGHT, WIDTH),
        batch_size=BATCH_SIZE,
        shuffle=True,
        seed=SEED,
    )

# %%
train_datagen_cls = datagen_cls(df_train_cls)
val_datagen_cls = datagen_cls(df_val_cls)
test_datagen_cls = datagen_cls(df_test_cls)
# Out:
# Found 24215 validated image filenames.
# Found 10000 validated image filenames.
# Found 10000 validated image filenames.

# %%
imgs = next(iter(train_datagen_cls))

i = 0
plt.imshow(imgs[0][i])
plt.title((label_mapping_inv(imgs[1][i]), float(imgs[1][i])))
plt.show()

del imgs

# %%
class Pooling(tf.keras.layers.Layer):
    def __init__(self, name='pooling', **kwargs):
        super().__init__(name=name, **kwargs)
    def build(self, input_shape):
        self.weight = self.add_weight(name='w', shape=(), initializer='ones')
        self.bias = self.add_weight(name='w', shape=(), initializer='zeros')
    def call(self, inputs):
        shape = tf.shape(inputs)
        new_shape = (shape[0], tf.math.reduce_prod(shape[1:]) )
        inputs = tf.reshape(inputs, new_shape)
        inputs_mean = tf.reduce_mean(inputs, axis=1, keepdims=True)
        outputs = inputs_mean*self.weight + self.bias
        return outputs

def unet_pool(base_model, input_size=(256, 256, 3)):
    inputs = Input(input_size)
    x = base_model(inputs)
    p = Pooling()(x)
    model = Model(inputs, p)
    return model

# %%
def categorical_accuracy(y_true, y_pred, weights=None):
    if weights is None:
        weights = np.ones_like(y_true)
    y_true = [label_mapping_inv(y) for y in y_true]
    y_pred = [label_mapping_inv(y) for y in y_pred]
    return accuracy_score(y_true, y_pred, sample_weight=weights)
def binary_accuracy(y_true, y_pred, weights=None):
    if weights is None:
        weights = np.ones_like(y_true)
    y_true = [label_mapping_inv(y)!='NonDemented' for y in y_true]
    y_pred = [label_mapping_inv(y)!='NonDemented' for y in y_pred]
    return accuracy_score(y_true, y_pred, sample_weight=weights)

# %%
model_seg = tf.keras.models.load_model(os.path.join(SAVE_PATH, 'trained_model_seg.keras'))
model_cls = unet_pool(model_seg, input_size=(HEIGHT, WIDTH, 3))
del model_seg

loss_fn = tf.keras.losses.BinaryCrossentropy(from_logits=True)
optim = tf.keras.optimizers.Adam(learning_rate=0.001)
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath=os.path.join(SAVE_PATH, 'model_cls_1.keras'), monitor='val_loss', save_best_only=True),
    tf.keras.callbacks.EarlyStopping(
        monitor='val_loss', mode='min', patience=10, restore_best_weights=True)
]
metrics = [
    tf.keras.metrics.MeanSquaredLogarithmicError(),
    # categorical_accuracy, binary_accuracy,
]

model_cls.compile(optimizer=optim, loss=loss_fn, metrics=metrics)
# Out:
# I0000 00:00:1744484475.538627    8064 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13762 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:1e.0, compute capability: 7.5
# /opt/tensorflow/lib/python3.12/site-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 90 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
history_cls = model_cls.fit(
    train_datagen_cls,
    # steps_per_epoch=df_train_cls.shape[0]//BATCH_SIZE,
    epochs=100,
    verbose=1,
    callbacks=callbacks,
    validation_data=val_datagen_cls,
    # validation_steps=df_val_cls.shape[0]//BATCH_SIZE,
)
# Out:
# Epoch 1/100
# /opt/tensorflow/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1
100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1066s 1s/step - loss: 0.3362 - mean_squared_logarithmic_error: 0.0515 - val_loss: 0.3530 - val_mean_squared_logarithmic_error: 0.0587
# Epoch 20/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1065s 1s/step - loss: 0.3316 - mean_squared_logarithmic_error: 0.0488 - val_loss: 0.3340 - val_mean_squared_logarithmic_error: 0.0543
# Epoch 21/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1065s 1s/step - loss: 0.3249 - mean_squared_logarithmic_error: 0.0511 - val_loss: 0.3328 - val_mean_squared_logarithmic_error: 0.0502
# Epoch 22/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1065s 1s/step - loss: 0.3280 - mean_squared_logarithmic_error: 0.0518 - val_loss: 0.3326 - val_mean_squared_logarithmic_error: 0.0530
# Epoch 23/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1065s 1s/step - loss: 0.3236 - mean_squared_logarithmic_error: 0.0521 - val_loss: 0.3351 - val_mean_squared_logarithmic_error: 0.0467
# Epoch 24/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1065s 1s/step - loss: 0.3246 - mean_squared_logarithmic_error: 0.0527 - val_loss: 0.3364 - val_mean_squared_logarithmic_error: 0.0573
# Epoch 25/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1064s 1s/step - loss: 0.3214 - mean_squared_logarithmic_error: 0.0535 - val_loss: 0.3415 - val_mean_squared_logarithmic_error: 0.0444
# Epoch 26/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1063s 1s/step - loss: 0.3186 - mean_squared_logarithmic_error: 0.0539 - val_loss: 0.3400 - val_mean_squared_logarithmic_error: 0.0576
# Epoch 27/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1063s 1s/step - loss: 0.3243 - mean_squared_logarithmic_error: 0.0566 - val_loss: 0.3275 - val_mean_squared_logarithmic_error: 0.0526
# Epoch 28/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1063s 1s/step - loss: 0.3306 - mean_squared_logarithmic_error: 0.0525 - val_loss: 0.3329 - val_mean_squared_logarithmic_error: 0.0576
# Epoch 29/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1063s 1s/step - loss: 0.3260 - mean_squared_logarithmic_error: 0.0532 - val_loss: 0.3349 - val_mean_squared_logarithmic_error: 0.0513
# Epoch 30/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1064s 1s/step - loss: 0.3210 - mean_squared_logarithmic_error: 0.0533 - val_loss: 0.3259 - val_mean_squared_logarithmic_error: 0.0573
# Epoch 31/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1062s 1s/step - loss: 0.3183 - mean_squared_logarithmic_error: 0.0565 - val_loss: 0.3612 - val_mean_squared_logarithmic_error: 0.0464
# Epoch 32/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1061s 1s/step - loss: 0.3342 - mean_squared_logarithmic_error: 0.0543 - val_loss: 0.3267 - val_mean_squared_logarithmic_error: 0.0535
# Epoch 33/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1062s 1s/step - loss: 0.3234 - mean_squared_logarithmic_error: 0.0562 - val_loss: 0.3277 - val_mean_squared_logarithmic_error: 0.0488
# Epoch 34/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1062s 1s/step - loss: 0.3272 - mean_squared_logarithmic_error: 0.0531 - val_loss: 0.3513 - val_mean_squared_logarithmic_error: 0.0635
# Epoch 35/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1063s 1s/step - loss: 0.3296 - mean_squared_logarithmic_error: 0.0569 - val_loss: 0.3248 - val_mean_squared_logarithmic_error: 0.0624
# Epoch 36/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1064s 1s/step - loss: 0.3217 - mean_squared_logarithmic_error: 0.0583 - val_loss: 0.3259 - val_mean_squared_logarithmic_error: 0.0633
# Epoch 37/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1062s 1s/step - loss: 0.3222 - mean_squared_logarithmic_error: 0.0562 - val_loss: 0.3255 - val_mean_squared_logarithmic_error: 0.0565
# Epoch 38/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1061s 1s/step - loss: 0.3242 - mean_squared_logarithmic_error: 0.0551 - val_loss: 0.3284 - val_mean_squared_logarithmic_error: 0.0536
# Epoch 39/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1062s 1s/step - loss: 0.3182 - mean_squared_logarithmic_error: 0.0537 - val_loss: 0.3298 - val_mean_squared_logarithmic_error: 0.0597
# Epoch 40/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1062s 1s/step - loss: 0.3263 - mean_squared_logarithmic_error: 0.0539 - val_loss: 0.3484 - val_mean_squared_logarithmic_error: 0.0669
# Epoch 41/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1063s 1s/step - loss: 0.3246 - mean_squared_logarithmic_error: 0.0541 - val_loss: 0.3251 - val_mean_squared_logarithmic_error: 0.0516
# Epoch 42/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1064s 1s/step - loss: 0.3142 - mean_squared_logarithmic_error: 0.0590 - val_loss: 0.3230 - val_mean_squared_logarithmic_error: 0.0630
# Epoch 43/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1063s 1s/step - loss: 0.3173 - mean_squared_logarithmic_error: 0.0538 - val_loss: 0.3271 - val_mean_squared_logarithmic_error: 0.0527
# Epoch 44/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1062s 1s/step - loss: 0.3241 - mean_squared_logarithmic_error: 0.0590 - val_loss: 0.3295 - val_mean_squared_logarithmic_error: 0.0628
# Epoch 45/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1064s 1s/step - loss: 0.3219 - mean_squared_logarithmic_error: 0.0569 - val_loss: 0.3226 - val_mean_squared_logarithmic_error: 0.0628
# Epoch 46/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1064s 1s/step - loss: 0.3207 - mean_squared_logarithmic_error: 0.0585 - val_loss: 0.3235 - val_mean_squared_logarithmic_error: 0.0671
# Epoch 47/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1066s 1s/step - loss: 0.3268 - mean_squared_logarithmic_error: 0.0547 - val_loss: 0.3222 - val_mean_squared_logarithmic_error: 0.0664
# Epoch 48/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1065s 1s/step - loss: 0.3248 - mean_squared_logarithmic_error: 0.0557 - val_loss: 0.3253 - val_mean_squared_logarithmic_error: 0.0526
# Epoch 49/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1064s 1s/step - loss: 0.3153 - mean_squared_logarithmic_error: 0.0546 - val_loss: 0.3223 - val_mean_squared_logarithmic_error: 0.0603
# Epoch 50/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1063s 1s/step - loss: 0.3174 - mean_squared_logarithmic_error: 0.0573 - val_loss: 0.3328 - val_mean_squared_logarithmic_error: 0.0620
# Epoch 51/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1062s 1s/step - loss: 0.3203 - mean_squared_logarithmic_error: 0.0531 - val_loss: 0.3369 - val_mean_squared_logarithmic_error: 0.0640
# Epoch 52/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1063s 1s/step - loss: 0.3240 - mean_squared_logarithmic_error: 0.0574 - val_loss: 0.3250 - val_mean_squared_logarithmic_error: 0.0752
# Epoch 53/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1064s 1s/step - loss: 0.3198 - mean_squared_logarithmic_error: 0.0573 - val_loss: 0.3222 - val_mean_squared_logarithmic_error: 0.0605
# Epoch 54/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1065s 1s/step - loss: 0.3249 - mean_squared_logarithmic_error: 0.0598 - val_loss: 0.3236 - val_mean_squared_logarithmic_error: 0.0640
# Epoch 55/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1065s 1s/step - loss: 0.3145 - mean_squared_logarithmic_error: 0.0570 - val_loss: 0.3261 - val_mean_squared_logarithmic_error: 0.0642
# Epoch 56/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1064s 1s/step - loss: 0.3167 - mean_squared_logarithmic_error: 0.0564 - val_loss: 0.3213 - val_mean_squared_logarithmic_error: 0.0639
# Epoch 57/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1063s 1s/step - loss: 0.3209 - mean_squared_logarithmic_error: 0.0578 - val_loss: 0.3414 - val_mean_squared_logarithmic_error: 0.0812
# Epoch 58/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1064s 1s/step - loss: 0.3292 - mean_squared_logarithmic_error: 0.0581 - val_loss: 0.3295 - val_mean_squared_logarithmic_error: 0.0573
# Epoch 59/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1063s 1s/step - loss: 0.3170 - mean_squared_logarithmic_error: 0.0600 - val_loss: 0.3392 - val_mean_squared_logarithmic_error: 0.0669
# Epoch 60/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1063s 1s/step - loss: 0.3185 - mean_squared_logarithmic_error: 0.0574 - val_loss: 0.3228 - val_mean_squared_logarithmic_error: 0.0646
# Epoch 61/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1062s 1s/step - loss: 0.3219 - mean_squared_logarithmic_error: 0.0565 - val_loss: 0.3214 - val_mean_squared_logarithmic_error: 0.0679
# Epoch 62/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1062s 1s/step - loss: 0.3150 - mean_squared_logarithmic_error: 0.0620 - val_loss: 0.3469 - val_mean_squared_logarithmic_error: 0.0775
# Epoch 63/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1062s 1s/step - loss: 0.3266 - mean_squared_logarithmic_error: 0.0611 - val_loss: 0.3251 - val_mean_squared_logarithmic_error: 0.0662
# Epoch 64/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1064s 1s/step - loss: 0.3241 - mean_squared_logarithmic_error: 0.0579 - val_loss: 0.3211 - val_mean_squared_logarithmic_error: 0.0638
# Epoch 65/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1064s 1s/step - loss: 0.3256 - mean_squared_logarithmic_error: 0.0581 - val_loss: 0.3211 - val_mean_squared_logarithmic_error: 0.0667
# Epoch 66/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1064s 1s/step - loss: 0.3205 - mean_squared_logarithmic_error: 0.0600 - val_loss: 0.3232 - val_mean_squared_logarithmic_error: 0.0656
# Epoch 67/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1063s 1s/step - loss: 0.3269 - mean_squared_logarithmic_error: 0.0576 - val_loss: 0.3249 - val_mean_squared_logarithmic_error: 0.0607
# Epoch 68/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1062s 1s/step - loss: 0.3162 - mean_squared_logarithmic_error: 0.0592 - val_loss: 0.3223 - val_mean_squared_logarithmic_error: 0.0669
# Epoch 69/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1062s 1s/step - loss: 0.3187 - mean_squared_logarithmic_error: 0.0648 - val_loss: 0.3236 - val_mean_squared_logarithmic_error: 0.0624
# Epoch 70/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1062s 1s/step - loss: 0.3223 - mean_squared_logarithmic_error: 0.0575 - val_loss: 0.3254 - val_mean_squared_logarithmic_error: 0.0672
# Epoch 71/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1063s 1s/step - loss: 0.3205 - mean_squared_logarithmic_error: 0.0595 - val_loss: 0.3237 - val_mean_squared_logarithmic_error: 0.0591
# Epoch 72/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1064s 1s/step - loss: 0.3199 - mean_squared_logarithmic_error: 0.0604 - val_loss: 0.3225 - val_mean_squared_logarithmic_error: 0.0663
# Epoch 73/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1063s 1s/step - loss: 0.3167 - mean_squared_logarithmic_error: 0.0621 - val_loss: 0.3217 - val_mean_squared_logarithmic_error: 0.0630
# Epoch 74/100
# 757/757 ━━━━━━━━━━━━━━━━━━━━ 1063s 1s/step - loss: 0.3188 - mean_squared_logarithmic_error: 0.0611 - val_loss: 0.3224 - val_mean_squared_logarithmic_error: 0.0689

# %%
model_cls.save(os.path.join(SAVE_PATH, 'trained_model_cls_1.keras'))

# %%
with open(os.path.join(SAVE_PATH, 'history_cls_1.json'), 'w') as outfile:
    json.dump(history_cls.history, outfile)

# %% [markdown]
# Training curves

# %%
plt.plot(history_cls.history['loss'], 'b-', label='Train Loss')
plt.plot(history_cls.history['val_loss'], 'b--', label='Val Loss')
plt.show()

# %%
plt.plot(history_cls.history['mean_squared_logarithmic_error'], 'r-', label='Train MSLE')
plt.plot(history_cls.history['val_mean_squared_logarithmic_error'], 'r--', label='Val MSLE')
plt.show()

# %%
# plt.plot(history_seg.history['binary_accuracy'], 'r-', label='Train Accuracy (b)')
# plt.plot(history_cls.history['categorical_accuracy'], 'b-', label='Train Accuracy (c)')
# plt.plot(history_cls.history['val_binary_accuracy'], 'r--', label='Train Accuracy (b)')
# plt.plot(history_cls.history['val_categorical_accuracy'], 'b--', label='Train Accuracy (c)')
# plt.show()

# %% [markdown]
# Validation set

# %%
true_score, pred_score = [], []
for idx, (img, lab, wgt) in enumerate(val_datagen_cls):
    true_score.extend(lab)
    score = tf.sigmoid(model_cls.predict(img, verbose=0))
    pred_score.extend(score)
    if idx == len(val_datagen_cls)-1:
        break
true_score = np.array(true_score).flatten()
pred_score = np.array(pred_score).flatten()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1744757328.397824   13027 service.cc:148] XLA service 0x7f62c400fc20 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1744757328.397850   13027 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2025-04-15 22:48:48.423813: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1744757328.519456   13027 cuda_dnn.cc:529] Loaded cuDNN version 90501
# 2025-04-15 22:48:48.942132: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,64,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,3,256,256]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 22:48:49.014696: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,64,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,64,256,256]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 22:48:51.518145: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,128,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,64,128,128]{3,2,1,0}, f32[128,64,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 22:48:53.095143: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,128,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,128,128,128]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 22:48:55.415257: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,256,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,128,64,64]{3,2,1,0}, f32[256,128,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 22:48:56.810598: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,256,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,256,64,64]{3,2,1,0}, f32[256,256,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 22:48:58.445507: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,512,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,256,32,32]{3,2,1,0}, f32[512,256,3,3]{3,2,1,0}, f32[512]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 22:48:59.648882: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,512,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,512,32,32]{3,2,1,0}, f32[512,512,3,3]{3,2,1,0}, f32[512]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 22:49:01.088605: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,256,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,768,64,64]{3,2,1,0}, f32[256,768,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 22:49:03.774249: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 27.44GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-04-15 22:49:04.105492: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,128,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,384,128,128]{3,2,1,0}, f32[128,384,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 22:49:06.804689: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 30.25GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-04-15 22:49:08.002397: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,64,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,192,256,256]{3,2,1,0}, f32[64,192,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 22:49:12.829937: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng11{k2=1,k3=0} for conv (f32[32,64,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,192,256,256]{3,2,1,0}, f32[64,192,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-04-15 22:49:12.870892: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.041041167s
# Trying algorithm eng11{k2=1,k3=0} for conv (f32[32,64,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,192,256,256]{3,2,1,0}, f32[64,192,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# I0000 00:00:1744757353.569404   13027 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2025-04-15 22:52:02.113008: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[16,64,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,3,256,256]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 22:52:02.150476: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[16,64,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,64,256,256]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 22:52:03.377467: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[16,128,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,64,128,128]{3,2,1,0}, f32[128,64,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 22:52:04.210217: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[16,128,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,128,128,128]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 22:52:05.813082: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[16,256,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,128,64,64]{3,2,1,0}, f32[256,128,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 22:52:06.821120: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[16,256,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,256,64,64]{3,2,1,0}, f32[256,256,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 22:52:08.194265: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[16,512,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,256,32,32]{3,2,1,0}, f32[512,256,3,3]{3,2,1,0}, f32[512]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 22:52:08.969879: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[16,512,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,512,32,32]{3,2,1,0}, f32[512,512,3,3]{3,2,1,0}, f32[512]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 22:52:10.134865: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[16,256,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,768,64,64]{3,2,1,0}, f32[256,768,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 22:52:11.765122: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 25.92GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-04-15 22:52:11.769234: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[16,128,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,384,128,128]{3,2,1,0}, f32[128,384,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 22:52:13.933680: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[16,64,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,192,256,256]{3,2,1,0}, f32[64,192,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}

# %%
idx = true_score.argsort()
plt.plot(pred_score[idx])
plt.plot(true_score[idx])
plt.show()

# %%
true_lab = np.array([label_mapping_inv(y) for y in true_score])
pred_lab = np.array([label_mapping_inv(y) for y in pred_score])

# %%
ConfusionMatrixDisplay.from_predictions(y_true=true_lab, y_pred=pred_lab);

# %% [markdown]
# Test/holdout set

# %%
true_score, pred_score = [], []
for idx, (img, lab, wgt) in enumerate(test_datagen_cls):
    true_score.extend(lab)
    pred = tf.sigmoid(model_cls.predict(img, verbose=0))
    pred_score.extend(pred)
    if idx == len(test_datagen_cls)-1:
        break
true_score = np.array(true_score).flatten()
pred_score = np.array(pred_score).flatten()
# Out:
# 2025-04-15 23:41:56.505398: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,64,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,3,256,256]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 23:41:56.566900: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,64,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,64,256,256]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 23:41:58.953722: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,128,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,64,128,128]{3,2,1,0}, f32[128,64,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 23:42:00.532406: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,128,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,128,128,128]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 23:42:03.037775: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,256,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,128,64,64]{3,2,1,0}, f32[256,128,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 23:42:04.483769: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,256,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,256,64,64]{3,2,1,0}, f32[256,256,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 23:42:06.185257: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,512,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,256,32,32]{3,2,1,0}, f32[512,256,3,3]{3,2,1,0}, f32[512]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 23:42:07.362474: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,512,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,512,32,32]{3,2,1,0}, f32[512,512,3,3]{3,2,1,0}, f32[512]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 23:42:08.803831: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,256,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,768,64,64]{3,2,1,0}, f32[256,768,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 23:42:11.498430: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 27.44GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-04-15 23:42:11.827085: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,128,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,384,128,128]{3,2,1,0}, f32[128,384,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 23:42:14.532711: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 30.25GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-04-15 23:42:15.731584: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[32,64,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,192,256,256]{3,2,1,0}, f32[64,192,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 23:42:20.516800: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng11{k2=1,k3=0} for conv (f32[32,64,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,192,256,256]{3,2,1,0}, f32[64,192,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-04-15 23:42:20.561124: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.044397205s
# Trying algorithm eng11{k2=1,k3=0} for conv (f32[32,64,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,192,256,256]{3,2,1,0}, f32[64,192,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-04-15 23:44:49.492002: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[16,64,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,3,256,256]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 23:44:49.529080: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[16,64,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,64,256,256]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 23:44:50.704092: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[16,128,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,64,128,128]{3,2,1,0}, f32[128,64,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 23:44:51.532937: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[16,128,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,128,128,128]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 23:44:53.098178: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[16,256,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,128,64,64]{3,2,1,0}, f32[256,128,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 23:44:53.950445: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[16,256,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,256,64,64]{3,2,1,0}, f32[256,256,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 23:44:55.565588: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[16,512,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,256,32,32]{3,2,1,0}, f32[512,256,3,3]{3,2,1,0}, f32[512]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 23:44:56.086186: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[16,512,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,512,32,32]{3,2,1,0}, f32[512,512,3,3]{3,2,1,0}, f32[512]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 23:44:57.251098: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[16,256,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,768,64,64]{3,2,1,0}, f32[256,768,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 23:44:58.877613: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 25.92GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-04-15 23:44:58.881652: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[16,128,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,384,128,128]{3,2,1,0}, f32[128,384,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}
# 2025-04-15 23:45:01.121296: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:557] Omitted potentially buggy algorithm eng14{k25=0} for conv (f32[16,64,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,192,256,256]{3,2,1,0}, f32[64,192,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]}

# %%
idx = true_score.argsort()
plt.plot(pred_score[idx])
plt.plot(true_score[idx])
plt.show()

# %%
true_lab = np.array([label_mapping_inv(y) for y in true_score])
pred_lab = np.array([label_mapping_inv(y) for y in pred_score])

# %%
ConfusionMatrixDisplay.from_predictions(y_true=true_lab, y_pred=pred_lab);

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,5))
ConfusionMatrixDisplay.from_predictions(
    y_true=true_lab, y_pred=pred_lab,
    im_kw=dict(vmin=0, vmax=1),
    xticks_rotation='vertical', ax=axes[0], normalize='true')
axes[0].set_title('Row-Normalized (Recall)')
ConfusionMatrixDisplay.from_predictions(
    y_true=true_lab, y_pred=pred_lab,
    im_kw=dict(vmin=0, vmax=1),
    xticks_rotation='vertical', ax=axes[1], normalize='pred')
axes[1].set_title('Column-Normalized (Precision)')
plt.show()

# %%
accuracy_score(true_lab, pred_lab), f1_score(true_lab, pred_lab, average='macro')
# Out:
# (0.9894, 0.9917489841843884)

# %%
ConfusionMatrixDisplay.from_predictions(
    y_true=true_lab!='NonDemented', y_pred=pred_lab!='NonDemented', colorbar=False);

# %%
accuracy_score(true_lab!='NonDemented', pred_lab!='NonDemented'), \
f1_score(true_lab!='NonDemented', pred_lab!='NonDemented', average='macro')
# Out:
# (0.99, 0.989798914571867)

# %% [markdown]
# ---
# ### Explainability

# %%
model_cls = tf.keras.models.load_model(
    os.path.join(SAVE_PATH, 'trained_model_cls_1.keras'), 
    custom_objects={'Pooling': Pooling},
)
# Out:
# I0000 00:00:1745079109.087961   69038 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13762 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:1e.0, compute capability: 7.5

# %%
def explainability(img, model):
    seg = model.layers[1](img)
    cls = model.layers[2](seg)
    # seg = tf.sigmoid(seg*model.layers[-1].weight + model.layers[-1].bias)
    cls = tf.sigmoid(cls)
    return seg.numpy().squeeze(), cls.numpy().squeeze()

# %%
imgs = next(iter(test_datagen_cls))

# %%
i = np.where(imgs[1]>imgs[1].max()-1e-4)[0][0]
out = explainability(imgs[0][[i],:,:,:], model_cls)

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14,6))
fig.suptitle(f'Label: {label_mapping_inv(imgs[1][i])} | Prediction: {out[1]}')
axes[0].imshow(imgs[0][i])
axes[1].imshow(out[0])
plt.show()

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(7,7))
ax.set_title(f'Label: {label_mapping_inv(imgs[1][i])}  |  Prediction: {out[1]}')
ax.set_xticks([])
ax.set_yticks([])
ax.imshow(imgs[0][i])
ax.imshow(out[0], alpha=0.55)
plt.show()
